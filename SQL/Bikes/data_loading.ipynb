# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine
import os

# %%
engine_mysql = create_engine("mysql+pymysql://root:1234@localhost:3306/practice")

try:
    engine_mysql
    print("Connected to mysql")
except:
    print("Unable to connect")
# Out:
# Connected to mysql

# %%
path = 'C:/Users/hp/OneDrive/Desktop/practice/SQL/Bikes/Data/'
# Out:
# 'C:/Users/hp/OneDrive/Desktop/practice/SQL/Bikes/Data/brands.csv'

# %%
os.chdir('Data')
print(os.listdir())

# %%
for i in os.listdir():
    df = pd.read_csv(path+i)
    name = i[:-4]
    df.to_sql(name=i, con = engine_mysql, if_exists='replace', index=False)

# %%
a = [1,2,3,4]

print(type(a))
# Out:
# <class 'list'>

# %%
print(type(a))
print(dir(a))
# Out:
# <class 'list'>
# ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %% [markdown]
# - ['__add__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__iadd__', '__imul__', '__init__', '__init_subclass__', '__iter__', '__le__', '__len__', '__lt__', '__mul__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__rmul__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'append', 'clear', 'copy', 'count', 'extend', 'index', 'insert', 'pop', 'remove', 'reverse', 'sort']

# %%
b = iter(a)
print(type(b))
print(dir(b))
# Out:
# <class 'list_iterator'>
# ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__length_hint__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__']

# %% [markdown]
# - ['__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__length_hint__', '__lt__', '__ne__', '__new__', '__next__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__']

# %% [markdown]
# - "we can see that the when "a" was "list(iterable)" it has only "__iter__" dunder method, but when it was converted into "b" and "iterator", now we have the "__iter__" and "__next__" dunder method

# %%
for i in a:
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
# print(next(b))
# print(next(b))
# print(next(b))
# print(next(b))
# #print(next(b)) --------> This will throw an error becasue b being an iterator only stores the current value and when used next method, it gives the next value, so when the values are over in the iterator, it throws an error

# %% [markdown]
# - we can not use the "__next__" dudner method for "a" as it is a "list(iterable)"

# %%
# If we want to see the result for this code, you have to comment the entire code above and run this code, as we have already gone through all the items in the "b"(iterator) so the below code might run, but it will show nothing

while True:
    try:
        item = next(b)
        print(item)
    except StopIteration:
        break
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# - iterator only moves forward, they can't be moved backwards
